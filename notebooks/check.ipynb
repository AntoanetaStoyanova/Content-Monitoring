# %%
import polars as pl

csv_path = r"C:\Users\antoa\Desktop\python-project\content-monitoring\data\collected_post.csv"

post = pl.read_csv(csv_path)
post.head()
# Out:
# shape: (5, 5)
# ┌───────────────────┬───────────────────┬───────────────────┬───────────────────┬──────────────────┐
# │ mot_cle           ┆ auteur            ┆ texte             ┆ date              ┆ category         │
# │ ---               ┆ ---               ┆ ---               ┆ ---               ┆ ---              │
# │ str               ┆ str               ┆ str               ┆ str               ┆ str              │
# ╞═══════════════════╪═══════════════════╪═══════════════════╪═══════════════════╪══════════════════╡
# │ economic policy   ┆ oldtrotter.bsky.s ┆ Which would       ┆ 2025-12-16T08:41: ┆ politique        │
# │                   ┆ ocial             ┆ suggest           ┆ 38.336Z           ┆ international    │
# │                   ┆                   ┆ rebuilding…       ┆                   ┆                  │
# │ photography       ┆ darkwaterphotos.b ┆ With that         ┆ 2025-12-16T12:19: ┆ art              │
# ...

# %%
import pandas as pd
csv_path = r"C:\Users\antoa\Desktop\python-project\content-monitoring\data\collected_post.csv"

post = pd.read_csv(csv_path)
post
# Out:
#                  mot_cle                          auteur  \
# 0             beaux arts                    mobilille.fr
# 1                theater        goodenough92.bsky.social
# 2      neo expressionism         supp3nhenn3.bsky.social
# 3        performance art           miel.honeyviolets.gay
# 4         graphic design              aulse.a-series.org
# ...                  ...                             ...
# 11652     political news    diogenesofsinope.bsky.social
# 11653            opinion  mediosdigitalessur.bsky.social
# 11654         street art            shlepcar.bsky.social
# 11655     conceptual art   evavazquezdibujos.bsky.social
# 11656    social services              m1ngle.bsky.social
#
#                                                    texte  \
# 0      🚇⛔️ M1 - Trafic interrompu en raison d'un défa...
# 1      They can eat potatoes and put on little plays ...
# 2      Today in History (1916): Hussein bin Ali, King...
# ...

# %%
post[post["category"]=="art"]
# Out:
#                      mot_cle                                       auteur  \
# 0                 beaux arts                                 mobilille.fr
# 1                    theater                     goodenough92.bsky.social
# 4             graphic design                           aulse.a-series.org
# 13     pure and applied arts                   justmayemoramx.bsky.social
# 14                   theater                rtvkrimpenerwaard.bsky.social
# ...                      ...                                          ...
# 11632            photography                           0zizoz.bsky.social
# 11634             beaux arts  richardmonvoisin.mastodon.social.ap.brid.gy
# 11635            applied art                       marycassat.bsky.social
# 11640            photography                           b2o6n4.bsky.social
# 11649                  music                   musictherapyuk.bsky.social
#
#                                                    texte  \
# ...
