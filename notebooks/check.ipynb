# %%
import pandas as pd
import os

csv_path = r"C:\Users\antoa\Desktop\python-project\test_mml\data\collected_post.csv"

post = pd.read_csv(csv_path)
post.head()
# Out:
#         mot_cle                    auteur  \
# 0      election          vala.bsky.social
# 1      election  joannkennedy.bsky.social
# 2    ecosysteme  leslieboulay.bsky.social
# 3    ecosysteme    tontonpogo.bsky.social
# 4  biodiversity  markscheflen.bsky.social
#
#                                                texte
# 0  More like 110% of what the far right were will...
# 1  What they do best \n\nCover ups \n\nHave you f...
# 2  Oui. le moyen et même le mauvais, ça fait part...
# 3  Fenêtre d'overton de gauche : notre écosystème...
# 4  Red-tailed Hawk a widespread North American ra...
